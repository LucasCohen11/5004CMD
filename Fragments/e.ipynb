# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'../data/Trips_Full Data.csv')

# %%
cols = [x for x in df.columns if 'Trips ' in x]

# %%
cols
# Out:
# ['Trips <1 Mile',
#  'Trips 1-25 Miles',
#  'Trips 1-3 Miles',
#  'Trips 10-25 Miles',
#  'Trips 100-250 Miles',
#  'Trips 100+ Miles',
#  'Trips 25-100 Miles',
#  'Trips 25-50 Miles',
#  'Trips 250-500 Miles',
#  'Trips 3-5 Miles',
#  'Trips 5-10 Miles',
#  'Trips 50-100 Miles',
#  'Trips 500+ Miles']

# %%
data = df[cols].sum()

# %%
data
# Out:
# Trips <1 Mile          2281834538
# Trips 1-25 Miles       7108888257
# Trips 1-3 Miles        2586336597
# Trips 10-25 Miles      1617549577
# Trips 100-250 Miles      47950910
# Trips 100+ Miles         84857312
# Trips 25-100 Miles      616262183
# Trips 25-50 Miles       484113920
# Trips 250-500 Miles      12804694
# Trips 3-5 Miles        1270890835
# Trips 5-10 Miles       1634111248
# Trips 50-100 Miles      132148263
# Trips 500+ Miles         24101708
# dtype: int64

# %%
data.plot(kind="bar")
plt.show()
